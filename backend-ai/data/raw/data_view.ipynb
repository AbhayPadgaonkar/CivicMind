# %%
import pandas as pd

# %%
df = pd.read_csv('civicmind.csv')

# %%
df
# Out:
#                                                complaint  \
# 0      Residents in the urban slum pocket reported en...
# 1      Residents in the new housing layout reported s...
# 2      Residents in the main market area reported une...
# 3      Residents in the bus terminal zone reported sa...
# 4      Residents in the new housing layout reported d...
# ...                                                  ...
# 69995  Residents in the urban slum pocket reported da...
# 69996  Residents in the dense residential colony repo...
# 69997  Residents in the school vicinity reported stor...
# 69998  Residents in the urban slum pocket reported st...
# 69999  Residents in the hospital surroundings reporte...
#
#                                               resolution  \
# 0      A phased intervention started with verificatio...
# 1      Following flow obstruction and capacity assess...
# 2      The response included temporary patching of da...
# ...

# %%
df.nunique()
# Out:
# complaint     70000
# resolution    11346
# department       10
# location         13
# population    61575
# severity          4
# priority          4
# risk_type        13
# risk_score     5848
# dtype: int64
