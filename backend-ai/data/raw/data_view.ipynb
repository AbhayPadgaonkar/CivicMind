# %%
import pandas as pd

# %%
df = pd.read_csv("civicmind_dataset.csv")

# %%
df1 =df[:29999]

# %%
df1['risk_type'].value_counts()
# Out:
# risk_type
# Public Health           7330
# Public Safety           3714
# Environmental Risk      3704
# Flood Risk              3668
# Infrastructure Risk     3667
# Regulatory Risk         3642
# Aesthetic               1024
# Resource Wastage         568
# Noise Nuisance           553
# Public Convenience       543
# Service Quality          540
# Facility Maintenance     528
# Service Delay            518
# Name: count, dtype: int64
